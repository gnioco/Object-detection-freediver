# %% [markdown]
# <a href="https://colab.research.google.com/github/gnioco/Object-detection-freediver/blob/main/Yolo8_Tiny.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 28.3 MB/s eta 0:00:00
# ...

# %%
# !unzip Obj19511.v1i.yolov8.zip -d /content/
# Out:
# Archive:  Obj19511.v1i.yolov8.zip
#   inflating: /content/README.dataset.txt
#   inflating: /content/README.roboflow.txt
#   inflating: /content/data.yaml
#    creating: /content/test/
#    creating: /content/test/images/
#  extracting: /content/test/images/00101-2-_png.rf.6365385f88445b5e0f6a57d72bddbf0c.jpg
#  extracting: /content/test/images/00501-3-_png.rf.b274c399e8f2868f025decde824fe189.jpg
#  extracting: /content/test/images/00701-2-_png.rf.4a76f1b34c7f260f5bbbce1e225b10db.jpg
#  extracting: /content/test/images/01101_png.rf.d8ce9b1c01e7ca9db0848d3ede3b7f93.jpg
#  extracting: /content/test/images/01701-4-_png.rf.fc388f86c1368d0d83cd62ec8d80aac6.jpg
#  extracting: /content/test/images/01801-3-_png.rf.9662921a37c593c4350034e94a8619a0.jpg
#  extracting: /content/test/images/01801-5-_png.rf.eb54c0ab64903016f1cd18afada196ab.jpg
#  extracting: /content/test/images/02101-2-_png.rf.47d5ad509dea99e5b8e3c19d98261369.jpg
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/data.yaml",
    epochs=50,
    imgsz=640,
    batch=16
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.4 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO("runs/detect/train/weights/best.pt")

results = model("/content/test/images/158401_png.rf.c17f60b1771fab971ce3863dc1c2ada2.jpg", conf=0.25)
# Out:
# image 1/1 /content/test/images/158401_png.rf.c17f60b1771fab971ce3863dc1c2ada2.jpg: 640x640 1 diver, 1 rope, 7.7ms
# Speed: 2.0ms preprocess, 7.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)

# %%
from ultralytics import YOLO

model = YOLO("runs/detect/train/weights/best.pt")

results = model("/content/test/images/228201_png.rf.89dba228f44dcfc843a057f7dfaf7b49.jpg", conf=0.25)
# Out:
# image 1/1 /content/test/images/228201_png.rf.89dba228f44dcfc843a057f7dfaf7b49.jpg: 640x640 3 divers, 1 rope, 7.9ms
# Speed: 2.0ms preprocess, 7.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)

# %%
results[0].show()
# Out:
# <PIL.Image.Image image mode=RGB size=640x640>

# %%
model = YOLO("runs/detect/train/weights/best.pt")

model.predict(
    source="/content/test/images",
    conf=0.25,
    save=True
)
# Out:
# image 1/112 /content/test/images/00101-2-_png.rf.6365385f88445b5e0f6a57d72bddbf0c.jpg: 640x640 (no detections), 8.1ms
# image 2/112 /content/test/images/00501-3-_png.rf.b274c399e8f2868f025decde824fe189.jpg: 640x640 1 rope, 7.2ms
# image 3/112 /content/test/images/00701-2-_png.rf.4a76f1b34c7f260f5bbbce1e225b10db.jpg: 640x640 2 ropes, 9.9ms
# image 4/112 /content/test/images/01101_png.rf.d8ce9b1c01e7ca9db0848d3ede3b7f93.jpg: 640x640 1 rope, 7.9ms
# image 5/112 /content/test/images/01701-4-_png.rf.fc388f86c1368d0d83cd62ec8d80aac6.jpg: 640x640 1 diver, 2 ropes, 7.2ms
# image 6/112 /content/test/images/01801-3-_png.rf.9662921a37c593c4350034e94a8619a0.jpg: 640x640 1 rope, 7.2ms
# image 7/112 /content/test/images/01801-5-_png.rf.eb54c0ab64903016f1cd18afada196ab.jpg: 640x640 1 diver, 3 ropes, 7.2ms
# image 8/112 /content/test/images/02101-2-_png.rf.47d5ad509dea99e5b8e3c19d98261369.jpg: 640x640 1 rope, 7.3ms
# ...

# %%
# !zip -r predict.zip /content/runs/detect/predict
# Out:
#   adding: content/runs/detect/predict/ (stored 0%)
#   adding: content/runs/detect/predict/136001_png.rf.b6b5f9f9603cff41449770be7cb411cc.jpg (deflated 11%)
#   adding: content/runs/detect/predict/208601_png.rf.a801a9ee03504628800eacb8d177af8e.jpg (deflated 13%)
#   adding: content/runs/detect/predict/100301-2-_png.rf.67f1a019ef495e4e2f299b44084732de.jpg (deflated 12%)
#   adding: content/runs/detect/predict/23901_png.rf.8b385554ffb842616ce511a820caeaa6.jpg (deflated 12%)
#   adding: content/runs/detect/predict/190001_png.rf.9fde2332f61e030219be01dccdac5189.jpg (deflated 15%)
#   adding: content/runs/detect/predict/172801_png.rf.1e9370fa2d8875375ded38ee16984dc7.jpg (deflated 10%)
#   adding: content/runs/detect/predict/24301_png.rf.1598f60a03994aedfa64cb58a8cdf6e8.jpg (deflated 14%)
#   adding: content/runs/detect/predict/133601_png.rf.dd921890cb04e719a1787dbd45554505.jpg (deflated 8%)
# ...

# %%
# !pip install pytube opencv-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 3.3 MB/s eta 0:00:00
# ...
